# %%
# !pip install pystan
# !conda install -c conda-forge fbprophet -y
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ...
# /bin/bash: line 1: conda: command not found

# %%
# !pip install --upgrade plotly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 72.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# ...

# %%
import prophet as pt

# %%
df=pd.read_csv('/content/airline_passengers.csv')

# %%
df
# Out:
#                                                  Month  \
# 0                                              1949-01
# 1                                              1949-02
# 2                                              1949-03
# 3                                              1949-04
# 4                                              1949-05
# ..                                                 ...
# 140                                            1960-09
# 141                                            1960-10
# 142                                            1960-11
# 143                                            1960-12
# 144  International airline passengers: monthly tota...
#
#      Thousands of Passengers
# 0                      112.0
# 1                      118.0
# 2                      132.0
# 3                      129.0
# 4                      121.0
# ..                       ...
# 140                    508.0
# 141                    461.0
# 142                    390.0
# ...

# %%
df.tail()
# Out:
#                                                  Month  \
# 140                                            1960-09
# 141                                            1960-10
# 142                                            1960-11
# 143                                            1960-12
# 144  International airline passengers: monthly tota...
#
#      Thousands of Passengers
# 140                    508.0
# 141                    461.0
# 142                    390.0
# 143                    432.0
# 144                      NaN

# %%
df=df.iloc[:144]
df
# Out:
#        Month  Thousands of Passengers
# 0    1949-01                    112.0
# 1    1949-02                    118.0
# 2    1949-03                    132.0
# 3    1949-04                    129.0
# 4    1949-05                    121.0
# ..       ...                      ...
# 139  1960-08                    606.0
# 140  1960-09                    508.0
# 141  1960-10                    461.0
# 142  1960-11                    390.0
# 143  1960-12                    432.0
#
# [144 rows x 2 columns]

# %%
# @title Thousands of Passengers

from matplotlib import pyplot as plt
df['Thousands of Passengers'].plot(kind='line', figsize=(8, 4), title='Thousands of Passengers')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.columns= ['ds','y']

# %%
df
# Out:
#           ds      y
# 0    1949-01  112.0
# 1    1949-02  118.0
# 2    1949-03  132.0
# 3    1949-04  129.0
# 4    1949-05  121.0
# ..       ...    ...
# 139  1960-08  606.0
# 140  1960-09  508.0
# 141  1960-10  461.0
# 142  1960-11  390.0
# 143  1960-12  432.0
#
# [144 rows x 2 columns]

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
df.tail()
# Out:
#             ds      y
# 139 1960-08-01  606.0
# 140 1960-09-01  508.0
# 141 1960-10-01  461.0
# 142 1960-11-01  390.0
# 143 1960-12-01  432.0

# %%
from prophet import Prophet

# %%
model=Prophet()

# %%
df.columns
# Out:
# Index(['ds', 'y'], dtype='object')

# %%
df.dropna(axis=0,inplace=True)

# %%
df.head()
# Out:
#           ds      y
# 0 1949-01-01  112.0
# 1 1949-02-01  118.0
# 2 1949-03-01  132.0
# 3 1949-04-01  129.0
# 4 1949-05-01  121.0

# %%
model.fit(df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiz0ze0z6/_nmx38j2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiz0ze0z6/sh01xc3x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37188', 'data', 'file=/tmp/tmpiz0ze0z6/_nmx38j2.json', 'init=/tmp/tmpiz0ze0z6/sh01xc3x.json', 'output', 'file=/tmp/tmpiz0ze0z6/prophet_model4f0dlswu/prophet_model-20240611200720.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:07:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:07:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
model.component_modes
# Out:
# {'additive': ['yearly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
df.tail()
# Out:
#             ds      y
# 139 1960-08-01  606.0
# 140 1960-09-01  508.0
# 141 1960-10-01  461.0
# 142 1960-11-01  390.0
# 143 1960-12-01  432.0

# %%
future_dates=model.make_future_dataframe(periods=365)

# %%
future_dates
# Out:
#             ds
# 0   1949-01-01
# 1   1949-02-01
# 2   1949-03-01
# 3   1949-04-01
# 4   1949-05-01
# ..         ...
# 504 1961-11-27
# 505 1961-11-28
# 506 1961-11-29
# 507 1961-11-30
# 508 1961-12-01
#
# [509 rows x 1 columns]

# %%
prediction=model.predict(future_dates)

# %%
prediction
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   1949-01-01  107.406338   57.348963  113.276857   107.406338   107.406338
# 1   1949-02-01  109.550561   50.543395  108.292710   109.550561   109.550561
# 2   1949-03-01  111.487279   83.762781  138.973909   111.487279   111.487279
# 3   1949-04-01  113.631502   79.115845  137.788492   113.631502   113.631502
# 4   1949-05-01  115.706556   83.050348  139.972272   115.706556   115.706556
# ..         ...         ...         ...         ...          ...          ...
# 504 1961-11-27  521.304699  472.660643  528.748406   520.694035   521.847965
# 505 1961-11-28  521.405720  469.382166  527.605457   520.792413   521.952075
# 506 1961-11-29  521.506741  469.424134  523.627522   520.890796   522.055902
# 507 1961-11-30  521.607762  463.418923  522.210802   520.989190   522.159963
# 508 1961-12-01  521.708783  461.861736  519.757213   521.087583   522.263855
#
# ...

# %%
model.plot(prediction)

# %%
model.plot_components(prediction); #use a ";" as a break...so that jupyter doesnt render matplotlib plot function again

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='730 days', period='180 days', horizon = '365 days')
df_cv.head()
# Out:
# INFO:prophet:Making 19 forecasts with cutoffs between 1951-01-18 00:00:00 and 1959-12-02 00:00:00
#   0%|          | 0/19 [00:00<?, ?it/s]
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiz0ze0z6/sqe__t1h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiz0ze0z6/0kaknj5s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19295', 'data', 'file=/tmp/tmpiz0ze0z6/sqe__t1h.json', 'init=/tmp/tmpiz0ze0z6/0kaknj5s.json', 'output', 'file=/tmp/tmpiz0ze0z6/prophet_modelkg4dbh_c/prophet_model-20240611202527.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:25:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:25:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# ...

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv) #y_hat and y compared for performance metrics
df_p.head()
# Out:
#   horizon          mse       rmse        mae      mape     mdape     smape  \
# 0 40 days  1089.760435  33.011520  25.888183  0.078584  0.073832  0.079624
# 1 42 days  1015.074527  31.860234  25.207161  0.076726  0.073832  0.077409
# 2 46 days   909.815509  30.163148  24.622042  0.078579  0.078888  0.078319
# 3 47 days  1044.416363  32.317431  26.737368  0.081351  0.085408  0.081498
# 4 48 days  1034.025454  32.156266  26.194461  0.079480  0.085408  0.079693
#
#    coverage
# 0  0.227273
# 1  0.181818
# 2  0.136364
# 3  0.136364
# 4  0.181818

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='rmse')

# %%
df_p #coverage is yhat upper-lower
# Out:
#      horizon          mse       rmse        mae      mape     mdape     smape  \
# 0    40 days  1089.760435  33.011520  25.888183  0.078584  0.073832  0.079624
# 1    42 days  1015.074527  31.860234  25.207161  0.076726  0.073832  0.077409
# 2    46 days   909.815509  30.163148  24.622042  0.078579  0.078888  0.078319
# 3    47 days  1044.416363  32.317431  26.737368  0.081351  0.085408  0.081498
# 4    48 days  1034.025454  32.156266  26.194461  0.079480  0.085408  0.079693
# ..       ...          ...        ...        ...       ...       ...       ...
# 165 359 days   766.600337  27.687548  21.654293  0.068947  0.062001  0.068551
# 166 360 days   770.123742  27.751103  21.933194  0.069808  0.062001  0.069431
# 167 362 days   864.691069  29.405630  23.203429  0.068900  0.062001  0.069029
# 168 364 days   838.273512  28.952953  22.134290  0.065984  0.050250  0.066210
# 169 365 days   980.885591  31.319093  24.017554  0.071239  0.059901  0.072069
#
#      coverage
# 0    0.227273
# ...

# %% [markdown]
# Using XGBoost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('/content/PJME_hourly.csv')
df = df.set_index('Datetime')
df.index = pd.to_datetime(df.index)

# %%
df.plot(style='.',
        figsize=(15, 5),
        color=color_pal[0],
        title='PJME Energy Use in MW')
plt.show()

# %%
train = df.loc[df.index < '01-01-2015']
test = df.loc[df.index >= '01-01-2015']

fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline('01-01-2015', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %%
df.loc[(df.index > '01-01-2010') & (df.index < '01-08-2010')] \
    .plot(figsize=(15, 5), title='Week Of Data')
plt.show()

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='hour', y='PJME_MW')
ax.set_title('MW by Hour')
plt.show()

# %%
train = create_features(train)
test = create_features(test)

FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
TARGET = 'PJME_MW'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:32605.13970	validation_1-rmse:31657.15729
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [12:03:05] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [100]	validation_0-rmse:12584.35462	validation_1-rmse:11747.28803
# [200]	validation_0-rmse:5837.33066	validation_1-rmse:5363.58554
# [300]	validation_0-rmse:3923.28511	validation_1-rmse:4020.48045
# [400]	validation_0-rmse:3447.54638	validation_1-rmse:3860.60088
# [500]	validation_0-rmse:3288.19208	validation_1-rmse:3816.37862
# [600]	validation_0-rmse:3206.55619	validation_1-rmse:3779.04119
# [700]	validation_0-rmse:3153.61368	validation_1-rmse:3754.45684
# [800]	validation_0-rmse:3114.34038	validation_1-rmse:3738.38209
# [900]	validation_0-rmse:3084.39550	validation_1-rmse:3730.01893
# [989]	validation_0-rmse:3059.85847	validation_1-rmse:3727.94591
# ...

# %%
#feature importance
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test['prediction'] = reg.predict(X_test)
df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df[['PJME_MW']].plot(figsize=(15, 5))
df['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Dat and Prediction')
plt.show()

# %%
ax = df.loc[(df.index > '04-01-2018') & (df.index < '04-08-2018')]['PJME_MW'] \
    .plot(figsize=(15, 5), title='Week Of Data')
df.loc[(df.index > '04-01-2018') & (df.index < '04-08-2018')]['prediction'] \
    .plot(style='.')
plt.legend(['Truth Data','Prediction'])
plt.show()
##model tuning is required for better results

# %%
score = np.sqrt(mean_squared_error(test['PJME_MW'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 3726.80

# %%
#calculating error
test['error'] = np.abs(test[TARGET] - test['prediction'])
test['date'] = test.index.date
test.groupby(['date'])['error'].mean().sort_values(ascending=False).head(10)
# Out:
# date
# 2016-08-13    12879.484619
# 2016-08-14    12772.887207
# 2015-02-20    11186.031494
# 2016-09-09    10966.513102
# 2016-09-10    10889.102214
# 2018-01-06    10642.975830
# 2016-08-12    10041.172689
# 2015-02-21     9988.168783
# 2015-02-16     9900.809326
# 2018-01-07     9852.571370
# Name: error, dtype: float64
